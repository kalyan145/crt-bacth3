# %% [markdown]
# # markdowns
# ## markdowns
# ### markdowns
# #### markdowns
# ##### markdowns

# %% [markdown]
# # *markdown*
# # **markdown**

# %% [markdown]
# [My Account](https://www.linkedin.com/in/sunil-mallari-28ab29198/)

# %% [markdown]
# ![image] (https://www.google.com/url?sa=i&source=images&cd=&cad=rja&uact=8&ved=2ahUKEwih65HC2ZjmAhUQX30KHWblDuoQjRx6BAgBEAQ&url=%2Furl%3Fsa%3Di%26source%3Dimages%26cd%3D%26ved%3D%26url%3Dhttps%253A%252F%252Fen.wikipedia.org%252Fwiki%252FGoogle_Images%26psig%3DAOvVaw3jPB3OS8lGpsfDR_rjajw2%26ust%3D1575434112339976&psig=AOvVaw3jPB3OS8lGpsfDR_rjajw2&ust=1575434112339976)

# %% [markdown]
# [1](https://drive.google.com/drive/my-drive)

# %%
print("hello gitam")
print("hi")
# Out:
# hello gitam
# hi

# %%
a=10 # single variable assignment

# %%
a="python"
b="p"
type(a)
# Out:
# str

# %%
a=10
print("a")
type(a)
# Out:
# a
# int

# %%
name =("sunil")
age =(20)
print(name,age)
# Out:
# sunil 20

# %%
a =int(input("enter a number"))
type (a)
# Out:
# enter a number10
# int

# %%
a =int(input("enter a number"))
b =int( input("enter a number"))
c = a+b
print(c)
type (c)
# Out:
# enter a number 1001
# enter a number 010100
# 11101
# int

# %%
z =2+3j
print (z)
type (z)
# Out:
# (2+3j)
# complex

# %%
z =complex(2,5)
print (z)
# Out:
# (2+5j)

# %%
complex(input("enter a number"))
